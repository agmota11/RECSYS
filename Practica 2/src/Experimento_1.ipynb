# %%
import pandas as pd
from datetime import datetime

# Load train and test CSV files into DataFrames
train_df = pd.read_csv('../data/train_reviews.csv')
test_df = pd.read_csv('../data/test_reviews.csv')

train_df.sample(10)
# Out:
#                      review_id                 user_id  \
# 341832  Ipt6_87IwndzpQmFMAHz4w  Y-80oPfUCkFXXQyC-Tz85w
# 884165  Qw1QGxTmeQiSL0B1wDnegg  v6nsU587W-PTTla8KcAcXg
# 63109   _n0SAatu23Gb7QpparVXmA  nPR_a87Qx30WdZEdmlMvkg
# 935899  PV-_jIrgLO7pzSh9v9hzHw  c42fPWkwxMjPBg0XSD8ZAw
# 754362  67MsaI9NQhmc-zggttsKrA  tJfV-r8EuxsTSOReSdCvEw
# 556078  LStpXdZNVxiIsxznZvz-oQ  O9NWKYmL0wGDL9Cpi6KfYQ
# 503868  zrZ186VfMxmdQFVf3YA8QA  DUvPrmI8wxRcrm0AuE94Zg
# 589953  AcI5dqzL8hBMF6lOMtGUZA  oGri5f_lTVa57ROM-ZMnlQ
# 940408  l7iL3gml9Yc4CGR11GUjnA  0xRCnqguuj3YcXGmpEf0NA
# 953611  I-kbqfU9A44YKVoZXb76Qg  BIZbhbY-JDrE6vUo-91jjg
#
#                    business_id  stars  useful  funny  cool  \
# 341832  Ly9dCC7Wa5qZAzUjZC_CPg    1.0       0      0     0
# 884165  00eSqUS2r4pm0dFZhZ3d1g    5.0       2      1     1
# 63109   idbdC3hdsJLXT4eHazaAiQ    3.0       0      0     0
# 935899  w18LqIckdMOK7-PU49KBsQ    1.0       0      0     0
# 754362  pkq0_n7jX5VwaWa01O2V1g    5.0       1      1     1
# 556078  rlOYB6tNebNam8ryLhrs0g    4.0       2      1     2
# 503868  lQwSrnzTxhssWHRGyq5rvQ    1.0       0      0     0
# 589953  jGD0eMV5Z7pAFmjv0rlSgQ    1.0       6      2     0
# 940408  dQZlvOEVNke30MY5iTiy1g    4.0       0      0     0
# 953611  ytynqOUb3hjKeJfRj5Tshw    4.0       0      0     0
#
#                                                      text                 date
# 341832  The women at the register should not be workin...  2018-08-07 00:53:54
# 884165  These truly are the "Best of Bucks."  The bage...  2009-11-16 18:00:15
# 63109   Decent meal. Been a few times, usually stuck w...  2012-11-08 22:01:12
# 935899  I tried to call and the number is disconnected...  2021-12-28 07:26:06
# 754362  Love this place! My favorite is the chicken cl...  2021-01-31 18:21:30
# 556078  I really enjoy coming in here , and grabbing a...  2012-04-04 17:38:47
# 503868  we paid close to $150 for one night. Not too b...  2018-11-27 00:10:06
# 589953  This was actaully the new location in the West...  2011-07-26 16:41:29
# 940408  Despite all the bad reviews on yelp , I actual...  2014-12-09 18:07:15
# 953611  Reading Terminal Market is amazing at least. P...  2014-11-02 17:56:43

# %%
test_df.sample(10)
# Out:
#                      review_id                 user_id  \
# 396092  ldQHqsKc_P0SEYGJILQxaA  MYjvo0LEoN5a4m8f8a_S_g
# 110505  Z_mvzI9gPw9KCgm0kA79cw  qD9QDamljY3Bm3pjcFpwAg
# 156775  IvfC4pAXsBrXbvFMbV_dHw  oFtL2nU_Q0LvQXWsRPtRCA
# 130688  z-UwwyVE-xq8DQ9VDZ1Zxw  S7h9IR_GJo4xhuP8F_PlXQ
# 199058  icPTFBjX60CxEpkLmEuT9A  5js99Lj8a4YTIVaUCgXovQ
# 113127  m6vfqEQwBDD1Vvsad8S9UQ  O9W8YV1mY1-wmkAFmowFpw
# 159038  muobh8ocPaRF5PUyyC0FTA  oNUNwiucQnASqMk4rYp2oA
# 227631  nWdtGzPTrvyV2zd-gYG-0Q  nPBgEhHiJ4UaZ5qQyrBLPQ
# 205470  eeRO1hmJg41LDoaaCAF7Dw  cEO0YT3uqwBqNAT87z88BQ
# 348086  0gJO3FdUmCgY8Ibff-SgDw  82Micw6atbqgn8-r7oNRKg
#
#                    business_id  useful  funny  cool  \
# 396092  M9YzrtbHvlntFXWoed9q0Q       2      0     0
# 110505  fnO03-RX7UDC1TzXETWEsQ       0      0     1
# 156775  2pXrwBssKTp30uxbQgl6kw       0      0     1
# 130688  OSrZ4BMMXaLSb5sxFpmA-g       1      0     0
# 199058  yKRdsPapsnpwaCs-SZcabg       1      0     0
# 113127  -5iuX3tPbwH5LpoWN9QhMQ       1      0     0
# 159038  F7J-Kc3fR0vdjcpN9TYLJw       0      0     0
# 227631  33zxFqIOe6Yg8qPXKkhUjg       0      0     0
# 205470  mNw3UU6PPUAeS31VKgM-qw       0      0     0
# 348086  dvph41fD_t6Kd_ChSpmNSA       1      1     0
#
#                                                      text                 date
# 396092  The food at Aman's is great, and the menu is e...  2008-09-05 01:28:57
# 110505  The cheesesteaks and pizza are out of this wor...  2009-08-03 01:34:39
# 156775  Nice and peaceful beach. I came here to avoid ...  2021-04-06 03:53:28
# 130688  I live very close to this place, and I have se...  2018-01-26 00:23:57
# 199058  Absolutely. Amazing. I have followed this truc...  2019-11-10 01:03:13
# 113127  Come every 6 months since our 9 year old son w...  2018-08-21 00:38:53
# 159038  Really awesome fries. Great strawberry shortca...  2017-03-13 01:19:37
# 227631  Great BBQ; hands down the best in Tampa Bay Ar...  2019-07-25 23:32:39
# 205470  Please. Please stop. I've been here twice. Thi...  2015-06-07 02:11:58
# 348086  Very nice! \n\nFrom the valet at the front doo...  2018-11-27 01:08:39

# %%
rating_distribution = train_df['stars'].value_counts().sort_index()
print(rating_distribution)
# Out:
# stars
# 1.0    148134
# 2.0     73595
# 3.0     93676
# 4.0    199493
# 5.0    452886
# Name: count, dtype: int64

# %%
# Calcular la moda de las calificaciones en el DataFrame de entrenamiento
rating_mode = train_df['stars'].mode()[0]

# Asignar la moda como calificación para todos los registros en el DataFrame de prueba
test_df['stars'] = rating_mode

# Exportar el resultado a un archivo CSV
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
output_path = f'../out/result_{timestamp}.csv'
test_df[['review_id', 'stars']].to_csv(output_path, index=False)

print(f"File saved to {output_path}")
test_df.sample(10)
# Out:
# File saved to ../out/result_20250408_212919.csv
#                      review_id                 user_id  \
# 216285  EcpDs6qr5I9rUyqVbg8jWQ  yIkSbUO6WM6Oc0fU7kXg8A
# 228486  URCUnCEryjb2fr5MQyngpw  fohO7EIe3J0a0oLmXgWv4Q
# 45157   KjRH8coMDysF8Kt2-6ceSQ  KSrQ-qr-dXCcJadevuS1RA
# 47353   3NiDHC5L5wpQxEE8zWoWOg  K8D22KUbpfCxvK91lt5sxw
# 393886  Ysor0cGASOHYKCOondJ6VA  FTZyZbr1eF7s3Ss7uSLcXQ
# 265694  BDSv12zz2L71G0Qdhcky1A  rslPC4SPqIEp06X20TUn3w
# 330232  V7BFB4sWL-va691iRkjQOA  Q7sy5ghubUm8LUDjHUO2Xw
# 130979  wiRQG6O4Z3RSwngnaN1WVg  2OlTfTUgTJUl7MqCwV27IQ
# 154619  cj9ON28ts7CjHowQeWAnRw  FqOipBsbfGGesYYrx9Zgxg
# 173681  hJfK3SaP5OunZMFdxxvnnQ  cjirS8KquGXn7fGaGBkEyg
#
#                    business_id  useful  funny  cool  \
# 216285  5KS5b5-ip8znhJS_CYdzeQ       1      1     1
# 228486  KjJDvCg5wuK-wyRy9OYJYQ       1      0     1
# 45157   BWITd9JUXP3gSi1z3Y-z8g       3      0     4
# 47353   DVBJRvnCpkqaYl6nHroaMg       1      0     1
# 393886  0JkPOvTyjnx2NbpYQBIkwA       1      0     1
# 265694  ytynqOUb3hjKeJfRj5Tshw       2      0     1
# 330232  UijMQu3VCy8VkDU_e1rs1w       2      0     0
# 130979  VSzb2pi2qG9IN7w1k5HfkA       0      0     0
# 154619  oQ5CPRt0R3AzFvcjNOqB1w       0      0     0
# 173681  b8E0zgTLKSsVzS566GHgXw       2      0     0
#
#                                                      text  \
# 216285  I really like this place, the beer, the staff,...
# 228486  I was sorry to see some of the low reviews. th...
# 45157   I biked 30+ minutes (one way) on the schuykill...
# 47353   Best vegan Mexican menu on southern Arizona. I...
# 393886  I'm a big dude and they actually had shoes tha...
# 265694  Simply the best!\n\nFoodies in Philly this pla...
# 330232  I would give it 5 stars if they were not allow...
# 130979  Hands down, the best ice cream I've ever had. ...
# 154619  Been here a few times. The pork sandwich is a ...
# 173681  We just came here for a late breakfast. The ou...
#
#                        date  stars
# 216285  2020-09-21 22:12:39    5.0
# 228486  2016-02-06 20:09:59    5.0
# 45157   2015-06-22 19:07:36    5.0
# 47353   2020-08-16 14:42:36    5.0
# 393886  2011-07-27 00:36:19    5.0
# 265694  2020-03-28 03:35:50    5.0
# 330232  2014-03-02 07:23:29    5.0
# 130979  2014-08-17 12:51:44    5.0
# 154619  2012-02-26 22:37:17    5.0
# 173681  2015-08-15 16:43:51    5.0

# %%
from datetime import datetime

rating_mode = train_df['stars'].mean()

test_df['stars'] = rating_mode.round(0)

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
output_path = f'../out/result_{timestamp}.csv'
test_df[['review_id', 'stars']].to_csv(output_path, index=False)

print(f"File saved to {output_path}")
test_df.sample(10)
# Out:
# File saved to ../out/result_20250408_213445.csv
#                      review_id                 user_id  \
# 239289  zTOanCjjXJiGCHaAnPgHuA  sqcEE_Wh8SJRrAsbqIQ2rw
# 43525   cw6u6U_v-Po1FtJhFSmdqw  sI2eMg-zZrKYUCRWncwv_g
# 127923  Oygy8HSUXx5AIUphuyMt1A  PB-0O-bd8GMpcS99yUyTfA
# 271753  M-DgDJcRdWbHpz3f16m-pg  m6Kty1Fef9TqoTwMku_rpQ
# 193150  JG4OGMdtaZ551bS0TXDV-g  c_qvPrvlVnwpt_hJGB3s6w
# 223448  7rZHNnPc4BZLu8DYusdsKg  nU-8KB6uoDkVwQ6lyyxL3g
# 123249  e7JcVp70fDtcZ4ckYBdb8A  RgDllwYfx2NCEZy644vPuQ
# 185292  yIfJr52b_BBXvYADGjGruQ  kgg_ZH7dYMjQIk6THGceiQ
# 371177  xdROvYbjw2_zV6MmPiHB3A  8msHKCMV33mgrWuHMZUF1w
# 59935   wW1u6A6HeZ9kDrIs0Rpwww  R_JZoTf-vz8IWHEX2JL8_A
#
#                    business_id  useful  funny  cool  \
# 239289  hc0KmC42EzjXbC83eMIDMg       0      0     0
# 43525   PV00aCrNGHZMruxVWUoKkQ       0      1     0
# 127923  UWOmb-ojD9xUaHI3odOCng       0      0     0
# 271753  Ns8vJxhsc5ygiX7Vff1bDQ       0      1     0
# 193150  OxhFfRWlpMib0VIiFsUicQ       0      0     0
# 223448  uoUZ8Wx7Aw7Nj6QIxaCjew       1      0     0
# 123249  FA5dYRukiu0ZdlsxX7ozNg       0      0     0
# 185292  NLV0ppsHTiJk6JVdFSxVAQ       1      0     1
# 371177  7cr-FYscJgV6rDnV7Wantw       0      0     0
# 59935   PpN7ZMEhfQaNm7qxVZ-nTg       0      0     0
#
#                                                      text  \
# 239289  I would rate this place 3-4 stars! I really li...
# 43525   In June 2020, I just received a full A/C insta...
# 127923  I have eaten at Old Chicago in several cities ...
# 271753  Great music in two spots downstairs and the co...
# 193150  Going through a major reconstruction.  Maybe i...
# 223448  The food was great! We ordered the chicken and...
# 123249  They are very pricey for brows on what is done...
# 185292  I finally tried 4 Seasons. They have both Chin...
# 371177  Waited over a hour for a croissant sandwich. I...
# 59935   Food is ok, but they nickel and dime you to de...
#
#                        date  stars
# 239289  2012-08-29 06:02:12    4.0
# 43525   2020-06-08 23:06:42    4.0
# 127923  2018-10-02 14:13:12    4.0
# 271753  2015-02-16 16:48:28    4.0
# 193150  2014-05-30 14:28:02    4.0
# 223448  2021-03-14 02:58:44    4.0
# 123249  2018-09-18 17:28:36    4.0
# 185292  2018-08-26 15:34:35    4.0
# 371177  2021-08-14 18:08:17    4.0
# 59935   2018-04-17 00:12:00    4.0
