# %%
import pandas as pd
import pandas as pd
import numpy as np
import random
import csv
from collections import defaultdict

# %%
# Load train and test CSV files into DataFrames
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')

df_train.sample(10)
# Out:
#          user    item  rating
# 51559    6236  129400     7.0
# 70953    9196  163891     7.0
# 24716    2684   79945    10.0
# 254963  48311   88661     6.0
# 241717  45223   21163     8.0
# 286172  54670     643     7.0
# 66679    8512   81893     5.0
# 63640    7906  151324     8.0
# 5992      534   39933     8.0
# 366665  72282  177443     2.0

# %%
df_test.sample(10)
# Out:
#           ID   user   item  rating
# 16683  16683    839   4644     5.0
# 11930  11930   4201  13354    10.0
# 17823  17823    534   1413    10.0
# 33574  33574   6740  17917     7.0
# 32946  32946  10548  24539     7.0
# 15224  15224   1959   7458     5.0
# 24856  24856   1357   2004     8.0
# 4366    4366   3711   2295     7.0
# 14121  14121   6010  16711     6.0
# 21023  21023   2639   9061    10.0

# %%
rating_distribution = df_train['rating'].value_counts().sort_index()
print(rating_distribution)
# Out:
# rating
# 1.0      1592
# 2.0      2478
# 3.0      5423
# 4.0      8042
# 5.0     45231
# 6.0     33489
# 7.0     69102
# 8.0     93366
# 9.0     60507
# 10.0    71121
# Name: count, dtype: int64

# %% [markdown]
# ## PMF

# %%
# Parámetros del modelo
NUM_FACTORS = 7
LEARNING_RATE = 0.001
REGULARIZATION = 0.1
NUM_ITERATIONS = 10
MIN_RATING = 0
MAX_RATING = 10

# %% [markdown]
# ### Hiperparámetros

# %%
from sklearn.model_selection import train_test_split

# Dividir datos de entrenamiento en train + validación
train_data, val_data = train_test_split(df_train, test_size=0.2, random_state=42)

# %%
def train_and_evaluate(train_df, val_df, num_factors, lr, reg, iterations):
    # Indexado
    user_ids = sorted(set(train_df['user']).union(val_df['user']))
    item_ids = sorted(set(train_df['item']).union(val_df['item']))
    user_to_index = {uid: idx for idx, uid in enumerate(user_ids)}
    item_to_index = {iid: idx for idx, iid in enumerate(item_ids)}
    num_users = len(user_ids)
    num_items = len(item_ids)

    ratings = {}
    for _, row in train_df.iterrows():
        u = user_to_index[row['user']]
        i = item_to_index[row['item']]
        ratings[(u, i)] = row['rating']

    rating_avg = sum(ratings.values()) / len(ratings)

    # Inicialización
    p = np.random.rand(num_users, num_factors)
    q = np.random.rand(num_items, num_factors)
    bu = np.random.rand(num_users)
    bi = np.random.rand(num_items)

    # Entrenamiento
    for _ in range(iterations):
        for (u, i), r in ratings.items():
            pred = rating_avg + bu[u] + bi[i] + np.dot(p[u], q[i])
            error = r - pred
            bu[u] += lr * (error - reg * bu[u])
            bi[i] += lr * (error - reg * bi[i])
            p[u] += lr * (error * q[i] - reg * p[u])
            q[i] += lr * (error * p[u] - reg * q[i])

    # Validación
    errors = []
    for _, row in val_df.iterrows():
        u = user_to_index.get(row['user'])
        i = item_to_index.get(row['item'])
        if u is not None and i is not None:
            pred = rating_avg + bu[u] + bi[i] + np.dot(p[u], q[i])
            pred = max(MIN_RATING, min(MAX_RATING, pred))
            errors.append(abs(row['rating'] - pred))
    return np.mean(errors)

# %%
param_grid = {
    "num_factors": [5, 10, 15, 20],
    "lr": [0.0001, 0.001, 0.01],
    "reg": [0.001, 0.05, 0.1, 0.5],
    "iterations": [10, 15, 20, 25, 30]
}

best_mae = float('inf')
best_config = None

for f in param_grid["num_factors"]:
    for lr in param_grid["lr"]:
        for reg in param_grid["reg"]:
            for iters in param_grid["iterations"]:
                print(f"Entrenando con factores={f}, lr={lr}, reg={reg}, iters={iters}")
                mae = train_and_evaluate(train_data, val_data, f, lr, reg, iters)
                print(f"MAE: {mae:.4f}")
                if mae < best_mae:
                    best_mae = mae
                    best_config = (f, lr, reg, iters)
    
print("\nMejores hiperparámetros encontrados:")
print(f"Factores: {best_config[0]}, LR: {best_config[1]}, Reg: {best_config[2]}, Iteraciones: {best_config[3]}")
print(f"MAE en validación: {best_mae:.4f}")
# Out:
# Entrenando con factores=5, lr=0.0001, reg=0.001, iters=10
# MAE: 2.0154
# Entrenando con factores=5, lr=0.0001, reg=0.001, iters=15
# MAE: 1.9691
# Entrenando con factores=5, lr=0.0001, reg=0.001, iters=20
# MAE: 1.9297
# Entrenando con factores=5, lr=0.0001, reg=0.001, iters=25
# MAE: 1.8936
# Entrenando con factores=5, lr=0.0001, reg=0.001, iters=30
# MAE: 1.8702
# Entrenando con factores=5, lr=0.0001, reg=0.05, iters=10
# MAE: 2.0164
# Entrenando con factores=5, lr=0.0001, reg=0.05, iters=15
# MAE: 1.9668
# Entrenando con factores=5, lr=0.0001, reg=0.05, iters=20
# MAE: 1.9236
# Entrenando con factores=5, lr=0.0001, reg=0.05, iters=25
# MAE: 1.8947
# Entrenando con factores=5, lr=0.0001, reg=0.05, iters=30
# MAE: 1.8640
# Entrenando con factores=5, lr=0.0001, reg=0.1, iters=10
# MAE: 2.0092
# Entrenando con factores=5, lr=0.0001, reg=0.1, iters=15
# MAE: 1.9637
# Entrenando con factores=5, lr=0.0001, reg=0.1, iters=20
# MAE: 1.9251
# Entrenando con factores=5, lr=0.0001, reg=0.1, iters=25
# MAE: 1.8921
# Entrenando con factores=5, lr=0.0001, reg=0.1, iters=30
# MAE: 1.8610
# Entrenando con factores=5, lr=0.0001, reg=0.5, iters=10
# MAE: 2.0023
# Entrenando con factores=5, lr=0.0001, reg=0.5, iters=15
# MAE: 1.9541
# Entrenando con factores=5, lr=0.0001, reg=0.5, iters=20
# MAE: 1.9114
# Entrenando con factores=5, lr=0.0001, reg=0.5, iters=25
# MAE: 1.8802
# Entrenando con factores=5, lr=0.0001, reg=0.5, iters=30
# MAE: 1.8488
# Entrenando con factores=5, lr=0.001, reg=0.001, iters=10
# MAE: 1.6855
# Entrenando con factores=5, lr=0.001, reg=0.001, iters=15
# MAE: 1.6268
# Entrenando con factores=5, lr=0.001, reg=0.001, iters=20
# MAE: 1.5887
# Entrenando con factores=5, lr=0.001, reg=0.001, iters=25
# MAE: 1.5603
# Entrenando con factores=5, lr=0.001, reg=0.001, iters=30
# MAE: 1.5385
# Entrenando con factores=5, lr=0.001, reg=0.05, iters=10
# MAE: 1.6804
# Entrenando con factores=5, lr=0.001, reg=0.05, iters=15
# MAE: 1.6228
# Entrenando con factores=5, lr=0.001, reg=0.05, iters=20
# MAE: 1.5864
# Entrenando con factores=5, lr=0.001, reg=0.05, iters=25
# MAE: 1.5590
# Entrenando con factores=5, lr=0.001, reg=0.05, iters=30
# MAE: 1.5354
# Entrenando con factores=5, lr=0.001, reg=0.1, iters=10
# MAE: 1.6810
# Entrenando con factores=5, lr=0.001, reg=0.1, iters=15
# MAE: 1.6217
# Entrenando con factores=5, lr=0.001, reg=0.1, iters=20
# MAE: 1.5841
# Entrenando con factores=5, lr=0.001, reg=0.1, iters=25
# MAE: 1.5567
# Entrenando con factores=5, lr=0.001, reg=0.1, iters=30
# MAE: 1.5338
# Entrenando con factores=5, lr=0.001, reg=0.5, iters=10
# MAE: 1.6711
# Entrenando con factores=5, lr=0.001, reg=0.5, iters=15
# MAE: 1.6154
# Entrenando con factores=5, lr=0.001, reg=0.5, iters=20
# MAE: 1.5774
# Entrenando con factores=5, lr=0.001, reg=0.5, iters=25
# MAE: 1.5497
# Entrenando con factores=5, lr=0.001, reg=0.5, iters=30
# MAE: 1.5311
# Entrenando con factores=5, lr=0.01, reg=0.001, iters=10
# MAE: 1.4436
# Entrenando con factores=5, lr=0.01, reg=0.001, iters=15
# MAE: 1.4401
# Entrenando con factores=5, lr=0.01, reg=0.001, iters=20
# MAE: 1.4472
# Entrenando con factores=5, lr=0.01, reg=0.001, iters=25
# MAE: 1.4626
# Entrenando con factores=5, lr=0.01, reg=0.001, iters=30
# MAE: 1.4695
# Entrenando con factores=5, lr=0.01, reg=0.05, iters=10
# MAE: 1.4317
# Entrenando con factores=5, lr=0.01, reg=0.05, iters=15
# MAE: 1.4192
# Entrenando con factores=5, lr=0.01, reg=0.05, iters=20
# MAE: 1.4224
# Entrenando con factores=5, lr=0.01, reg=0.05, iters=25
# MAE: 1.4285
# Entrenando con factores=5, lr=0.01, reg=0.05, iters=30
# MAE: 1.4314
# Entrenando con factores=5, lr=0.01, reg=0.1, iters=10
# MAE: 1.4252
# Entrenando con factores=5, lr=0.01, reg=0.1, iters=15
# MAE: 1.4116
# Entrenando con factores=5, lr=0.01, reg=0.1, iters=20
# MAE: 1.4102
# Entrenando con factores=5, lr=0.01, reg=0.1, iters=25
# MAE: 1.4087
# Entrenando con factores=5, lr=0.01, reg=0.1, iters=30
# MAE: 1.4125
# Entrenando con factores=5, lr=0.01, reg=0.5, iters=10
# MAE: 1.4201
# Entrenando con factores=5, lr=0.01, reg=0.5, iters=15
# MAE: 1.3998
# Entrenando con factores=5, lr=0.01, reg=0.5, iters=20
# MAE: 1.3888
# Entrenando con factores=5, lr=0.01, reg=0.5, iters=25
# MAE: 1.3793
# Entrenando con factores=5, lr=0.01, reg=0.5, iters=30
# MAE: 1.3779
# Entrenando con factores=10, lr=0.0001, reg=0.001, iters=10
# MAE: 2.2091
# Entrenando con factores=10, lr=0.0001, reg=0.001, iters=15
# MAE: 2.1520
# Entrenando con factores=10, lr=0.0001, reg=0.001, iters=20
# MAE: 2.1080
# Entrenando con factores=10, lr=0.0001, reg=0.001, iters=25
# MAE: 2.0661
# Entrenando con factores=10, lr=0.0001, reg=0.001, iters=30
# MAE: 2.0320
# Entrenando con factores=10, lr=0.0001, reg=0.05, iters=10
# MAE: 2.2065
# Entrenando con factores=10, lr=0.0001, reg=0.05, iters=15
# MAE: 2.1492
# Entrenando con factores=10, lr=0.0001, reg=0.05, iters=20
# MAE: 2.1057
# Entrenando con factores=10, lr=0.0001, reg=0.05, iters=25
# MAE: 2.0642
# Entrenando con factores=10, lr=0.0001, reg=0.05, iters=30
# MAE: 2.0305
# Entrenando con factores=10, lr=0.0001, reg=0.1, iters=10
# MAE: 2.2076
# Entrenando con factores=10, lr=0.0001, reg=0.1, iters=15
# MAE: 2.1523
# Entrenando con factores=10, lr=0.0001, reg=0.1, iters=20
# MAE: 2.1026
# Entrenando con factores=10, lr=0.0001, reg=0.1, iters=25
# MAE: 2.0650
# Entrenando con factores=10, lr=0.0001, reg=0.1, iters=30
# MAE: 2.0294
# Entrenando con factores=10, lr=0.0001, reg=0.5, iters=10
# MAE: 2.1992
# Entrenando con factores=10, lr=0.0001, reg=0.5, iters=15
# MAE: 2.1392
# Entrenando con factores=10, lr=0.0001, reg=0.5, iters=20
# MAE: 2.0924
# Entrenando con factores=10, lr=0.0001, reg=0.5, iters=25
# MAE: 2.0498
# Entrenando con factores=10, lr=0.0001, reg=0.5, iters=30
# MAE: 2.0145
# Entrenando con factores=10, lr=0.001, reg=0.001, iters=10
# MAE: 1.8010
# Entrenando con factores=10, lr=0.001, reg=0.001, iters=15
# MAE: 1.7280
# Entrenando con factores=10, lr=0.001, reg=0.001, iters=20
# MAE: 1.6855
# Entrenando con factores=10, lr=0.001, reg=0.001, iters=25
# MAE: 1.6527
# Entrenando con factores=10, lr=0.001, reg=0.001, iters=30
# MAE: 1.6209
# Entrenando con factores=10, lr=0.001, reg=0.05, iters=10
# MAE: 1.8004
# Entrenando con factores=10, lr=0.001, reg=0.05, iters=15
# MAE: 1.7281
# Entrenando con factores=10, lr=0.001, reg=0.05, iters=20
# MAE: 1.6833
# Entrenando con factores=10, lr=0.001, reg=0.05, iters=25
# MAE: 1.6458
# Entrenando con factores=10, lr=0.001, reg=0.05, iters=30
# MAE: 1.6180
# Entrenando con factores=10, lr=0.001, reg=0.1, iters=10
# MAE: 1.7968
# Entrenando con factores=10, lr=0.001, reg=0.1, iters=15
# MAE: 1.7274
# Entrenando con factores=10, lr=0.001, reg=0.1, iters=20
# MAE: 1.6784
# Entrenando con factores=10, lr=0.001, reg=0.1, iters=25
# MAE: 1.6437
# Entrenando con factores=10, lr=0.001, reg=0.1, iters=30
# MAE: 1.6159
# Entrenando con factores=10, lr=0.001, reg=0.5, iters=10
# MAE: 1.7835
# Entrenando con factores=10, lr=0.001, reg=0.5, iters=15
# MAE: 1.7115
# Entrenando con factores=10, lr=0.001, reg=0.5, iters=20
# MAE: 1.6642
# Entrenando con factores=10, lr=0.001, reg=0.5, iters=25
# MAE: 1.6299
# Entrenando con factores=10, lr=0.001, reg=0.5, iters=30

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from joblib import Parallel, delayed
import csv
from collections import defaultdict

# Cargar datos completos
df = pd.read_csv("../data/train.csv")
df_test = pd.read_csv("../data/test.csv")

# Dividir en entrenamiento y validación
df_train, df_val = train_test_split(df, test_size=0.2, random_state=42)

# Indexado de usuarios e ítems
user_ids = sorted(set(df_train['user']).union(df_val['user']).union(df_test['user']))
item_ids = sorted(set(df_train['item']).union(df_val['item']).union(df_test['item']))

user_to_index = {uid: idx for idx, uid in enumerate(user_ids)}
item_to_index = {iid: idx for idx, iid in enumerate(item_ids)}

NUM_USERS = len(user_ids)
NUM_ITEMS = len(item_ids)

# Diccionarios para ratings
ratings = {}
user_items = defaultdict(set)

for _, row in df_train.iterrows():
    u = user_to_index[row['user']]
    i = item_to_index[row['item']]
    r = row['rating']
    ratings[(u, i)] = r
    user_items[u].add(i)

# Media de las valoraciones
rating_average = sum(ratings.values()) / len(ratings)

# Búsqueda de hiperparámetros
param_grid = {
    'NUM_FACTORS': [5, 10, 15, 20],
    'NUM_ITERATIONS': [10, 20, 30, 50],
    'LEARNING_RATE': [0.001, 0.005, 0.01],
    'REGULARIZATION': [0.01, 0.1, 0.5]
}

# Función para entrenar el modelo y calcular MAE
def train_and_evaluate(params):
    p = np.random.rand(NUM_USERS, params['NUM_FACTORS'])
    q = np.random.rand(NUM_ITEMS, params['NUM_FACTORS'])
    bu = np.random.rand(NUM_USERS)
    bi = np.random.rand(NUM_ITEMS)

    def compute_biased_prediction(avg, b_u, b_i, p_u, q_i):
        return avg + b_u + b_i + np.dot(p_u, q_i)

    # Entrenamiento
    for it in range(params['NUM_ITERATIONS']):
        for (u, i), rating in ratings.items():
            pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
            error = rating - pred

            bu[u] += params['LEARNING_RATE'] * (error - params['REGULARIZATION'] * bu[u])
            bi[i] += params['LEARNING_RATE'] * (error - params['REGULARIZATION'] * bi[i])

            p[u] += params['LEARNING_RATE'] * (error * q[i] - params['REGULARIZATION'] * p[u])
            q[i] += params['LEARNING_RATE'] * (error * p[u] - params['REGULARIZATION'] * q[i])

    # Evaluación con el conjunto de validación
    val_mae = []
    for _, row in df_val.iterrows():
        u_raw, i_raw, actual_rating = row['user'], row['item'], row['rating']
        u = user_to_index.get(u_raw)
        i = item_to_index.get(i_raw)
        if u is not None and i is not None:
            pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
            val_mae.append(abs(actual_rating - pred))

    mae = np.mean(val_mae) if val_mae else float('inf')
    print(f"Probando parámetros: {params} -> MAE: {mae}")
    return params, mae

# Paralelización de la búsqueda de hiperparámetros
results = Parallel(n_jobs=12, backend="loky")(delayed(train_and_evaluate)(params) for params in ParameterGrid(param_grid))

# Obtener los mejores parámetros
best_params, best_mae = min(results, key=lambda x: x[1])
print("Mejores hiperparámetros:", best_params)
print(f"Mejor MAE: {best_mae:.4f}")
# Out:
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.7210371625398713
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.716158631243736
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.7020375498454894
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.6115365068247864
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.617581444700255
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 2.0442177182798154
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.599012222544092
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 2.036282574356523
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 2.0044457939150524
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.5607304274481968
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.5607386002965151
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.5481754551587599
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.856564288609112
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.8470027749637765
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.8205642814850533
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.4987847235547187
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.5050960757399443
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.494158253393966
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 2.3649214240482244
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.7701578607003954
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 2.3574314466412583
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 2.3034671550218646
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.7310193350246714
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.7593857213379207
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 2.098419525366737
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 2.0825611962498387
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 2.0431634505125578
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.6808844665108031
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.6396049442680263
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.6668760444814528
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.976355590074354
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 2.656254840586161
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 2.6441157590968207
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.961812778744425
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.9200282006659528
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 2.590880419128157
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 2.326529711785785
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 2.308169702905822
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.8595706262820046
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 2.2529876559646023
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.8396143519108703
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.7940156373469187
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.504459276272374
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 2.1691225255660576
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 2.1571932937005576
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.4988295081033634
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.4924693979011798
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 2.0983541415616433
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.4577964876848222
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.4423971025067845
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.4334845615030394
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.9448158784430036
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.6779646492673088
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 2.007688998706246
# Probando parámetros: {'LEARNING_RATE': 0.001, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 2.0343962303135745
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.6643202810286615
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.6407282996454309
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.4265213004649453
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.4573673855100708
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.4114902383501557
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.6106813488335998
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.5825017567262532
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.5468163079922932
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.4233428580745664
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.4802892062608548
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.3888027223825692
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.8509669438022749
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.8364386885042263
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.557889409534391
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.6110537034561558
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.7911326309606177
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.5144107952887267
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.765666102570638
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.728042428880009
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.675442570306023
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.6334290854571822
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.5478209437958796
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.4784020226541992
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 2.022132807672498
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 2.005583849267314
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.9451881632748593
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.7595133112506556
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.6958440675443316
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.6260521305017466
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.9322720553472663
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.8782889484584329
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.8037789935752253
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.683188990020134
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.7829234272312309
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.5806008899954473
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.4605721612565816
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.4437226547094348
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.4341983883865341
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.9202878567150257
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.8401726249678831
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.7425703936908323
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.461700273008375
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.4224818123722474
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.398966772495165
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.9335262032916505
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.8225305282340978
# Probando parámetros: {'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.689338972398928
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.6088110684066554
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.5810727162520712
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.547691245662787
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.4912450025261488
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.430781479712597
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.3869581971304445
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.6175818787924874
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.551674211727627
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.491921828060051
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.5259447635256176
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.4415776220915604
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.3777654467460583
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.7716717038579548
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.6415953376775838
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.7321265250788394
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.671191960573078
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.5492354951723482
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.4693680712344561
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.774138847468025
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.6903042349281054
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.5963469825032777
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.6664136833385954
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.4495669442348436
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 10, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.5499497741127592
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.01} -> MAE: 1.9209910812761284
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.1} -> MAE: 1.873556025071233
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 10, 'REGULARIZATION': 0.5} -> MAE: 1.8021394026724686
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.7928023521056842
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.6779375385194182
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.5663157314904457
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.01} -> MAE: 1.9287015491847679
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.1} -> MAE: 1.8290100415965114
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 20, 'REGULARIZATION': 0.5} -> MAE: 1.7087017324277274
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.8059977345262188
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.6626692231611266
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 15, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.5341142526378357
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.01} -> MAE: 1.9399018401654453
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.1} -> MAE: 1.8117958586428204
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 30, 'REGULARIZATION': 0.5} -> MAE: 1.6680749230521583
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01} -> MAE: 1.9414098626924936
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.1} -> MAE: 1.7904076462960923
# Probando parámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5} -> MAE: 1.6231497796031398
# Mejores hiperparámetros: {'LEARNING_RATE': 0.01, 'NUM_FACTORS': 5, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.5}
# Mejor MAE: 1.3778

# %%
import pandas as pd
import numpy as np
import csv
from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch
from collections import defaultdict

# Parámetros del modelo
# Parámetros del modelo predeterminados
NUM_FACTORS = 20
LEARNING_RATE = 0.005
REGULARIZATION = 0.01
NUM_ITERATIONS = 50
MIN_RATING = 0
MAX_RATING = 10

# Cargar datos
from sklearn.model_selection import train_test_split

df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')

# División del conjunto de entrenamiento en train y validación
df_train, df_val = train_test_split(df_train, test_size=0.2, random_state=42)

# Indexado de usuarios e ítems
user_ids = sorted(set(df_train['user']).union(df_test['user']))
item_ids = sorted(set(df_train['item']).union(df_test['item']))

user_to_index = {uid: idx for idx, uid in enumerate(user_ids)}
item_to_index = {iid: idx for idx, iid in enumerate(item_ids)}

NUM_USERS = len(user_ids)
NUM_ITEMS = len(item_ids)

# Diccionario de ratings
train_ratings = {}
user_items = defaultdict(set)

# Rellenar el diccionario de ratings
for _, row in df_train.iterrows():
    u = user_to_index[row['user']]
    i = item_to_index[row['item']]
    r = row['rating']
    train_ratings[(u, i)] = r
    user_items[u].add(i)

# Cálculo de la media de valoraciones
rating_average = sum(train_ratings.values()) / len(train_ratings)

# Inicialización aleatoria
p = np.random.rand(NUM_USERS, NUM_FACTORS)
q = np.random.rand(NUM_ITEMS, NUM_FACTORS)
bu = np.random.rand(NUM_USERS)
bi = np.random.rand(NUM_ITEMS)

# Predicción con sesgos
def compute_biased_prediction(avg, b_u, b_i, p_u, q_i):
    return avg + b_u + b_i + np.dot(p_u, q_i)


# Función de entrenamiento
def train_pmf(config):
    for it in range(NUM_ITERATIONS):
        for (u, i), rating in train_ratings.items():
            pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
            error = rating - pred

            # Actualización de parámetros
            bu[u] += config['learning_rate'] * (error - config['regularization'] * bu[u])
            bi[i] += config['learning_rate'] * (error - config['regularization'] * bi[i])
            p[u] += config['learning_rate'] * (error * q[i] - config['regularization'] * p[u])
            q[i] += config['learning_rate'] * (error * p[u] - config['regularization'] * q[i])

    # Evaluación en el conjunto de validación
    val_errors = []
    for _, row in df_val.iterrows():
        u = user_to_index.get(row['user'])
        i = item_to_index.get(row['item'])
        if u is not None and i is not None:
            pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
            val_errors.append(abs(row['rating'] - pred))

    mean_val_mae = np.mean(val_errors)
    tune.report({"score": mean_val_mae})

# Configuración de búsqueda
search_space = {
    'learning_rate': tune.loguniform(0.001, 0.01),
    'regularization': tune.loguniform(0.001, 0.1),
    'num_factors': tune.uniform(5, 20),
    'num_iterations': tune.uniform(20, 100)
}

# Ejecución de la búsqueda con Tuner
tuner = tune.Tuner(
    train_pmf,
    param_space=search_space,
    tune_config=tune.TuneConfig(
        metric="score",
        mode="min",
        num_samples=50,
        max_concurrent_trials=1,
        search_alg=BayesOptSearch()
    ),
    run_config=tune.RunConfig(
        storage_path="/home/corti/RECSYS/Practica 1/tune"
    )
)
results = tuner.fit()

# Guardar mejores resultados
print("Mejores hiperparámetros encontrados:")
best_result = results.get_best_result()
print(best_result.config)

# Generación de predicciones para el conjunto de prueba
output_rows = []
for _, row in df_test.iterrows():
    test_id = row['ID']
    u_raw = row['user']
    i_raw = row['item']
    u = user_to_index.get(u_raw)
    i = item_to_index.get(i_raw)
    if u is not None and i is not None:
        pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
        pred = round(max(MIN_RATING, min(MAX_RATING, pred)), 3)
    else:
        pred = 8.0
    output_rows.append((test_id, pred))

# Guardar predicciones en CSV
filename = "/home/corti/RECSYS/Practica 1/tune/predicciones_PMF_raytune.csv"
with open(filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["ID", "rating"])
    writer.writerows(output_rows)

print(f"Archivo '{filename}' generado correctamente.")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-03-29 13:57:09</td></tr>
# <tr><td>Running for: </td><td>00:01:17.46        </td></tr>
# <tr><td>Memory:      </td><td>9.8/15.6 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/16 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name        </th><th>status  </th><th>loc                 </th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  num_factors</th><th style="text-align: right;">  num_iterations</th><th style="text-align: right;">  regularization</th></tr>
# </thead>
# <tbody>
# <tr><td>train_pmf_85559104</td><td>RUNNING </td><td>172.30.202.84:215805</td><td style="text-align: right;">     0.00437086</td><td style="text-align: right;">      19.2607</td><td style="text-align: right;">         78.5595</td><td style="text-align: right;">       0.0602672</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>

# %% [markdown]
# ### Ejecución

# %%
#'LEARNING_RATE': 0.005, 'NUM_FACTORS': 20, 'NUM_ITERATIONS': 50, 'REGULARIZATION': 0.01

# Parámetros del modelo
NUM_FACTORS = 20
LEARNING_RATE = 0.005
REGULARIZATION = 0.01
NUM_ITERATIONS = 50
MIN_RATING = 0
MAX_RATING = 10

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# Indexado de usuarios e items
user_ids = sorted(set(df_train['user']).union(df_test['user']))
item_ids = sorted(set(df_train['item']).union(df_test['item']))

user_to_index = {uid: idx for idx, uid in enumerate(user_ids)}
item_to_index = {iid: idx for idx, iid in enumerate(item_ids)}

NUM_USERS = len(user_ids)
NUM_ITEMS = len(item_ids)

# Diccionarios para ratings
ratings = {}
user_items = defaultdict(set)

for _, row in df_train.iterrows():
    u = user_to_index[row['user']]
    i = item_to_index[row['item']]
    r = row['rating']
    ratings[(u, i)] = r
    user_items[u].add(i)

# Media de las valoraciones
rating_average = sum(ratings.values()) / len(ratings)

# Inicialización aleatoria
p = np.random.rand(NUM_USERS, NUM_FACTORS)
q = np.random.rand(NUM_ITEMS, NUM_FACTORS)
bu = np.random.rand(NUM_USERS)
bi = np.random.rand(NUM_ITEMS)

# Predicción con sesgos
def compute_biased_prediction(avg, b_u, b_i, p_u, q_i):
    return avg + b_u + b_i + np.dot(p_u, q_i)

# Entrenamiento
for it in range(NUM_ITERATIONS):
    print(f"Iteración {it+1} de {NUM_ITERATIONS}")

    for (u, i), rating in ratings.items():
        pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
        error = rating - pred

        # Actualización de parámetros
        bu[u] += LEARNING_RATE * (error - REGULARIZATION * bu[u])
        bi[i] += LEARNING_RATE * (error - REGULARIZATION * bi[i])

        p[u] += LEARNING_RATE * (error * q[i] - REGULARIZATION * p[u])
        q[i] += LEARNING_RATE * (error * p[u] - REGULARIZATION * q[i])

# Generar predicciones para test
output_rows = []

for _, row in df_test.iterrows():
    test_id = row['ID']
    u_raw = row['user']
    i_raw = row['item']

    u = user_to_index.get(u_raw)
    i = item_to_index.get(i_raw)

    if u is not None and i is not None:
        pred = compute_biased_prediction(rating_average, bu[u], bi[i], p[u], q[i])
        pred = round(max(MIN_RATING, min(MAX_RATING, pred)), 3)
    else:
        pred = 8.0  # Valor neutro si no hay datos

    output_rows.append((test_id, pred))

# Guardar CSV
with open("predicciones_PMF_20_0.005_0.01_50.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["ID", "rating"])
    writer.writerows(output_rows)

print("Archivo generado correctamente.")
